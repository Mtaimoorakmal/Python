# %%
from PIL import Image
Image.open('dp.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=825x851>

# %%
from rembg import remove

img = Image.open('dp.png')
output = remove(img)
output.save("dp12.png")

# %%
Image.open("dp12.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=825x851>
